# %%
df = spark.read.format('json')\
        .load('/Volumes/parent_cata/delta_lake/volume/retail_orders_parquet/_delta_log/00000000000000000000.json')
df.display()

# %%
display(dbutils.fs.ls('/Volumes/parent_cata/delta_lake/volume/retail_orders_parquet/'))
