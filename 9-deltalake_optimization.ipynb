# %%
df = spark.read.table('parent_cata.delta_lake.retail_orders')

display(df)

# %%
df.write.format('delta')\
    .mode('append')\
    .save('/Volumes/parent_cata/delta_lake/volume/optimization9/')

# %%
# %sql
OPTIMIZE delta.`/Volumes/parent_cata/delta_lake/volume/optimization9/`

# %%
# %sql
describe history delta.`/Volumes/parent_cata/delta_lake/volume/optimization9/`

# %%
# %sql
optimize delta.`/Volumes/parent_cata/delta_lake/volume/optimization9/` ZORDER BY (order_id)

# %% [markdown]
# # **liquid clustering**

# %%
# %sql
ALTER TABLE parent_cata.delta_lake.retail_orders
CLUSTER BY AUTO
