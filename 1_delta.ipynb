# %%
df = spark.read.table('parent_cata.delta_lake.retail_orders')

display(df)

# %%
df.write.format('delta')\
    .mode('overwrite')\
    .saveAsTable('parent_cata.delta_lake.retail_orders')

# %% [markdown]
# **# save as parquet**

# %%
path = '/Volumes/parent_cata/delta_lake/volume/retail_orders_parquet'

df.write.format('delta')\
    .mode('overwrite')\
    .save(path)

# %%
# %sql
SELECT * FROM

# %%
display(dbutils.fs.ls('/Volumes/parent_cata/delta_lake/volume/retail_orders_parquet/'))
