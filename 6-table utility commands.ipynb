# %%
# %sql
DESCRIBE DETAIL DELTA.`/Volumes/parent_cata/delta_lake/deltalog_schema/chapter5/`

# %%
# %sql
DESCRIBE EXTENDED DELTA.`/Volumes/parent_cata/delta_lake/deltalog_schema/chapter5/`

# %%
# %sql
DESCRIBE HISTORY DELTA.`/Volumes/parent_cata/delta_lake/deltalog_schema/chapter5/`

# %%
# %sql
SELECT * FROM DELTA.`/Volumes/parent_cata/delta_lake/deltalog_schema/chapter5/`

# %%
df = spark.read.format('delta')\
        .load('/Volumes/parent_cata/delta_lake/deltalog_schema/chapter5/')

display(df)

# %%
# %sql
RESTORE DELTA.`/Volumes/parent_cata/delta_lake/deltalog_schema/chapter5/` TO VERSION AS OF 1

# %%
# %sql
SHOW TBLPROPERTIES DELTA.`/Volumes/parent_cata/delta_lake/deltalog_schema/chapter5/`

# %%
# %sql
CREATE TABLE parent_cata.delta_lake.chapter5_clone
DEEP CLONE DELTA.`/Volumes/parent_cata/delta_lake/deltalog_schema/chapter5/`
