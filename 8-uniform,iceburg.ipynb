# %%
df = spark.sql('select * from delta.`/Volumes/parent_cata/delta_lake/deltalog_schema/chapter5/`')

# %%
df.write.format('delta')\
    .saveAsTable('parent_cata.delta_lake.8uniform')

# %%
# %sql
CREATE TABLE parent_cata.delta_lake.8uniform2
USING DELTA TBLPROPERTIES (
  'delta.enableIcebergcompatV2' = 'true',
  'delta.universalFormat.enabledFormats' = 'iceberg'
)
