# %%
df = spark.read.table('parent_cata.delta_lake.retail_orders')

display(df)

# %%
# %sql
alter table parent_cata.delta_lake.retail_orders
SET tblproperties(delta.enableChangeDataFeed = true)

# %%
# %sql
insert into parent_cata.delta_lake.retail_orders
values
(1, 101, 'Test Product', 'Test Category', 2, 19.99, 'Pending', DATE('2025-11-05'), 0.0, DATE('2025-11-10'))

# %%
# %sql
update parent_cata.delta_lake.retail_orders
set status = 'testing123'
where customer_id = 101

# %%
# %sql
delete from parent_cata.delta_lake.retail_orders
where customer_id = '103'

# %%
# %sql
DESCRIBE HISTORY parent_cata.delta_lake.retail_orders

# %%
# %sql
SELECT * FROM table_changes('parent_cata.delta_lake.retail_orders',4)
